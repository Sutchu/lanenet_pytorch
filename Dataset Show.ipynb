# %%
import os.path as ops
import numpy as np
import torch
import cv2
import sys
sys.path.append('..')
from dataset.dataset_utils import TUSIMPLE, TusimpleAUG

# %% [markdown]
# # Build The datasets

# %%
# root = '/Users/smiffy/Documents/GitHub/TUSIMPLE/Data_Tusimple_PyTorch/training'
root = './TUSIMPLE/txt_for_local'

train_set = TUSIMPLE(root=root, flag='train')
valid_set = TUSIMPLE(root=root, flag='valid')
test_set = TUSIMPLE(root=root, flag='test')

print('train_set length {}'.format(len(train_set)))
print('valid_set length {}'.format(len(valid_set)))
print('test_set length {}'.format(len(test_set)))
# Out:
# train_set length 0
# valid_set length 0
# test_set length 0

# %%
train_set

# %%
gt, bgt, igt = train_set[20]
print('image type {}'.format(type(gt)))
print('image size {} \n'.format(gt.size()))

print('gt binary image type {}'.format(type(bgt)))
print('gt binary image size {}'.format(bgt.size()))
print('items in gt binary image {} \n'.format(torch.unique(bgt)))

print('gt instance type {}'.format(type(igt)))
print('gt instance size {}'.format(igt.size()))
print('items in gt instance {} \n'.format(torch.unique(igt)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-2cb7d6bfea4e> in <module>
# ----> 1 gt, bgt, igt = train_set[20]
#       2 print('image type {}'.format(type(gt)))
#       3 print('image size {} \n'.format(gt.size()))
#       4
#       5 print('gt binary image type {}'.format(type(bgt)))
#
# ~/PycharmProjects/lanenet_pytorch/dataset/dataset_utils.py in __getitem__(self, idx)
#      41
#      42     def __getitem__(self, idx):
# ---> 43         gt_image = cv2.imread(self.img_pathes[idx][0], cv2.IMREAD_UNCHANGED)
#      44         gt_binary_image = cv2.imread(self.img_pathes[idx][1], cv2.IMREAD_UNCHANGED)
#      45         gt_instance = cv2.imread(self.img_pathes[idx][2], cv2.IMREAD_UNCHANGED)
#
# IndexError: list index out of range

# %% [markdown]
# # Show the images

# %%
image_show = ((gt.numpy() + 1) * 127.5).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-144b060f42c1> in <module>
# ----> 1 image_show = ((gt.numpy() + 1) * 127.5).astype(int)
#
# NameError: name 'gt' is not defined

# %%
image_show.shape
# Out:
# (3, 256, 512)

# %%
import matplotlib.pyplot as plt
# image_show = image_show[...,::-1]
plt.figure(figsize=(15,15))
image_show = image_show.transpose(1,2,0)
image_show = image_show[...,::-1]
plt.imshow(image_show)

# %%
bgt.shape
# Out:
# torch.Size([256, 512])

# %%
plt.figure(figsize=(20,20))
ax1 = plt.subplot(121)
plt.imshow(bgt, cmap='gray')
ax1 = plt.subplot(122)
plt.imshow(igt, cmap='gray')

# %% [markdown]
# # Aug Dataset

# %%
# root = '/Users/smiffy/Documents/GitHub/TUSIMPLE/Data_Tusimple_PyTorch/training'
root = '../TUSIMPLE/txt_for_local'

train_set = TusimpleAUG(root=root, flag='train')
valid_set = TusimpleAUG(root=root, flag='valid')
test_set = TusimpleAUG(root=root, flag='test')

print('train_set length {}'.format(len(train_set)))
print('valid_set length {}'.format(len(valid_set)))
print('test_set length {}'.format(len(test_set)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-bd9a991d2b9c> in <module>
#       2 root = '../TUSIMPLE/txt_for_local'
#       3
# ----> 4 train_set = TusimpleAUG(root=root, flag='train')
#       5 valid_set = TusimpleAUG(root=root, flag='valid')
#       6 test_set = TusimpleAUG(root=root, flag='test')
#
# ~/PycharmProjects/lanenet_pytorch/dataset/dataset_utils.py in __init__(self, root, transforms, resize, flag)
#      90             file_open = self.test_file
#      91
# ---> 92         with open(file_open, 'r') as file:
#      93             data = file.readlines()
#      94             for d in data:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../TUSIMPLE/txt_for_local/train.txt'

# %%
idx = 280
gt, bgt, igt = train_set[idx]
gt_aug, bgt_aug, igt_aug = train_set[idx+1]
print('image type {}'.format(type(gt)))
print('image size {} \n'.format(gt.size()))

print('gt binary image type {}'.format(type(bgt)))
print('gt binary image size {}'.format(bgt.size()))
print('items in gt binary image {} \n'.format(torch.unique(bgt)))

print('gt instance type {}'.format(type(igt)))
print('gt instance size {}'.format(igt.size()))
print('items in gt instance {} \n'.format(torch.unique(igt)))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-21a6055fef67> in <module>
#       1 idx = 280
# ----> 2 gt, bgt, igt = train_set[idx]
#       3 gt_aug, bgt_aug, igt_aug = train_set[idx+1]
#       4 print('image type {}'.format(type(gt)))
#       5 print('image size {} \n'.format(gt.size()))
#
# ~/PycharmProjects/lanenet_pytorch/dataset/dataset_utils.py in __getitem__(self, idx)
#     120             gt_instance = cv2.flip(gt_instance, 1)
#     121
# --> 122         gt_image = cv2.resize(gt_image, dsize=self.resize, interpolation=cv2.INTER_LINEAR)
#     123         gt_binary_image = cv2.resize(gt_binary_image, dsize=self.resize, interpolation=cv2.INTER_NEAREST)
#     124         gt_instance = cv2.resize(gt_instance, dsize=self.resize, interpolation=cv2.INTER_NEAREST)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-1syr35c1/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
image_show = ((gt.numpy() + 1) * 127.5).astype(int)
image_show_aug = ((gt_aug.numpy() + 1) * 127.5).astype(int)
image_show.shape
# Out:
# (3, 256, 512)

# %%
import matplotlib.pyplot as plt
# image_show = image_show[...,::-1]
plt.figure(figsize=(20,20))
ax1 = plt.subplot(121)
image_show = image_show.transpose(1,2,0)
image_show = image_show[...,::-1]
plt.imshow(image_show)

ax1 = plt.subplot(122)
image_show_aug = image_show_aug.transpose(1,2,0)
image_show_aug = image_show_aug[...,::-1]
plt.imshow(image_show_aug)

plt.show()

# %%
plt.figure(figsize=(20,20))
ax1 = plt.subplot(121)
plt.imshow(bgt, cmap='gray')
ax1 = plt.subplot(122)
plt.imshow(igt, cmap='gray')

# %%
plt.figure(figsize=(20,20))
ax1 = plt.subplot(121)
plt.imshow(bgt_aug, cmap='gray')
ax1 = plt.subplot(122)
plt.imshow(igt_aug, cmap='gray')
